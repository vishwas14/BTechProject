# %% [markdown]
# <a href="https://colab.research.google.com/github/vishwas14/BTechProject/blob/main/BTP1stHalf.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **BTP: "Fiction, Markets and Trends: Analyzing narratives through a digital lens"**
# ### By: Arindam Dubey, Naman Sharma, Vishwas Anil Kumar

# %% [markdown]
# ## **Libraries Used**

# %%
import numpy as np
import pandas as pd
import nltk
from nltk import *
from nltk.corpus import stopwords
nltk.download('punkt')
nltk.download('stopwords')
nltk.download('wordnet')
from wordcloud import WordCloud
from tabulate import tabulate
import string
import matplotlib.pyplot as plt 
import re
lemmatizer = WordNetLemmatizer()
stopwords = stopwords.words("english")
from nltk import FreqDist
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Unzipping corpora/wordnet.zip.

# %% [markdown]
# ## **Pre-processing**

# %%
#data preprocessing
def to_lowercase(text):
    return  text.lower()
def remove_numbers(text):
    result = re.sub(r'\d+', '', text)
    return result
def remove_punctuation(text):
    text = re.sub(r'[“|”|‘|’]',' ',text)
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)
def remove_whitespace(text):
    return " ".join(text.split())
def lemmatize_word(text):
    word_tokens = word_tokenize(text)
    lemmas = [lemmatizer.lemmatize(word, pos='v') for word in word_tokens]
    return lemmas

file1 = open('T11.txt','r')
file2 = open('T22.txt','r')
text1 = file1.read()
text2= file2.read()


text1 = to_lowercase(text1)
text1 = remove_numbers(text1)
text1 = remove_punctuation(text1)
text1 = remove_whitespace(text1)
text1_tokenized = lemmatize_word(text1)

print("\n\nNumber Of Tokens in T1->",len(text1_tokenized))
print("Number of Vocab in T1->",len(set(text1_tokenized)))

text2 = to_lowercase(text2)
text2 = remove_numbers(text2)
text2 = remove_punctuation(text2)
text2 = remove_whitespace(text2)
text2_tokenized = lemmatize_word(text2)

print("\n\nNumber Of Tokens in T2->",len(text2_tokenized))
print("Number of Vocab in T2->",len(set(text2_tokenized)),"\n\n")
# Out:
# Number Of Tokens in T1-> 73731
# Number of Vocab in T1-> 5343
#
#
# Number Of Tokens in T2-> 7041
# Number of Vocab in T2-> 1365

# %% [markdown]
# ## **Novel 1 : Half Girlfriend**

# %%
wfreq1=[text1_tokenized.count(w) for w in text1_tokenized]
temp1 = {}
temp1 = (dict(zip(text1_tokenized,wfreq1)))
keys = temp1.keys()
values = temp1.values()

# %%
sorted_dict = {}
sorted_keys = sorted(temp1, key=temp1.get,reverse = True)  

for w in sorted_keys:
    sorted_dict[w] = temp1[w]

sorted_dict
# Out:
# {'i': 3429,
#  'the': 2815,
#  'to': 2017,
#  'be': 1735,
#  'say': 1717,
#  'a': 1643,
#  'you': 1291,
#  'and': 1244,
#  'she': 1226,
#  'in': 1113,
#  'have': 1103,
#  'my': 1046,
#  'her': 911,
#  'it': 879,
#  'of': 859,
#  'me': 849,
#  't': 843,
#  's': 586,
#  'he': 526,
#  'do': 520,
#  'on': 499,
#  'for': 484,
#  'what': 450,
#  'we': 446,
#  'with': 438,
#  'at': 436,
#  'riya': 408,
#  'that': 391,
#  'not': 331,
#  'from': 320,
#  'want': 307,
#  'as': 297,
#  'like': 289,
#  'this': 287,
#  'go': 283,
#  'up': 280,
#  'come': 272,
#  'so': 257,
#  'look': 253,
#  'they': 252,
#  'but': 235,
#  'his': 231,
#  'can': 228,
#  'out': 225,
#  'all': 223,
#  'no': 223,
#  'take': 217,
#  'know': 217,
#  'if': 212,
#  'don': 209,
#  'mother': 205,
#  'your': 204,
#  'will': 193,
#  'one': 189,
#  'madhav': 189,
#  'about': 186,
#  'make': 185,
#  'would': 180,
#  'how': 179,
#  'leave': 175,
#  'or': 173,
#  'didn': 173,
#  'an': 172,
#  'time': 170,
#  'get': 164,
# ...

# %%
fdist1 = FreqDist(text1_tokenized)
print("\n\n\tPlot of 10 Tokens with maximum frequency in T1")
fdist1.plot(10)
# Out:
# 	Plot of 10 Tokens with maximum frequency in T1

# %%
zipf_dict1 = {}
a = sorted_dict['i']
for w in sorted_dict:
    zipf_dict1[w] = sorted_dict[w]/a

zipf_dict1
# Out:
# {'i': 1.0,
#  'the': 0.820939049285506,
#  'to': 0.5882181393992417,
#  'be': 0.5059784193642461,
#  'say': 0.5007290755322251,
#  'a': 0.479148439778361,
#  'you': 0.3764946048410615,
#  'and': 0.36278798483522895,
#  'she': 0.3575386410032079,
#  'in': 0.32458442694663164,
#  'have': 0.3216681248177311,
#  'my': 0.30504520268299795,
#  'her': 0.2656751239428405,
#  'it': 0.2563429571303587,
#  'of': 0.2505103528725576,
#  'me': 0.24759405074365703,
#  't': 0.2458442694663167,
#  's': 0.17089530475357248,
#  'he': 0.15339749198016914,
#  'do': 0.15164771070282881,
#  'on': 0.14552347623213766,
#  'for': 0.14114902303878682,
#  'what': 0.13123359580052493,
#  'we': 0.13006707494896472,
#  'with': 0.12773403324584426,
#  'at': 0.12715077282006415,
#  'riya': 0.1189851268591426,
#  'that': 0.11402741324001167,
#  'not': 0.09652960046660834,
#  'from': 0.09332166812481774,
#  'want': 0.08953047535724701,
#  'as': 0.08661417322834646,
#  'like': 0.08428113152522601,
# ...

# %%
fdist11 = FreqDist(zipf_dict1)
print("\n\n\tPlot of 10 Tokens with maximum frequency in T1")
fdist11.plot(10)


x = np.linspace(1, 10, 20)
y = 1/(x**0.45)
plt.plot(x, y, 'b')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph of 1/x')
plt.show()
# Out:
# 	Plot of 10 Tokens with maximum frequency in T1

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = list(zipf_dict1.keys())
y1 = list(zipf_dict1.values())
x2 = np.linspace(1, 10, 20)
y2 = 1/(x**0.45)

fig, ax1 = plt.subplots()

ax2 = ax1.twiny() 

curve1, = ax1.plot(x1[:10],y1[:10] , label="Novel", color='g')
curve2, = ax2.plot(x2, y2, label="1/x^(0.45)", color='b')

curves = [curve1, curve2]

ax1.legend() 
ax2.legend() 
ax1.legend(curves, [curve.get_label() for curve in curves])
ax2.legend(curves, [curve.get_label() for curve in curves]) 
plt.title("Graph between 1/x^(0.45) and T1")
plt.show()

# %% [markdown]
# ## **Novel 2: The Blue Umbrella**

# %%
wfreq2=[text2_tokenized.count(w) for w in text2_tokenized]
temp2 = {}
temp2 = (dict(zip(text2_tokenized,wfreq2)))
keys2 = temp2.keys()
values2 = temp2.values()

# %%
sorted_dict2 = {}
sorted_keys2 = sorted(temp2, key=temp2.get,reverse = True)  

for w in sorted_keys2:
    sorted_dict2[w] = temp2[w]

sorted_dict2
# Out:
# {'the': 504,
#  'be': 205,
#  'and': 205,
#  'it': 179,
#  'a': 178,
#  'to': 160,
#  'of': 135,
#  'she': 131,
#  'have': 126,
#  'binya': 108,
#  'umbrella': 105,
#  'he': 102,
#  'in': 100,
#  'her': 96,
#  's': 70,
#  'on': 59,
#  'but': 59,
#  'that': 58,
#  'for': 54,
#  'his': 54,
#  'you': 53,
#  't': 49,
#  'with': 44,
#  'bijju': 43,
#  'ram': 42,
#  'bharosa': 40,
#  'say': 38,
#  'as': 37,
#  'they': 33,
#  'come': 33,
#  'up': 31,
#  'shop': 31,
#  'out': 30,
#  'or': 29,
#  'at': 28,
#  'give': 28,
#  'down': 27,
#  'blue': 26,
#  'from': 26,
#  'what': 25,
#  'him': 25,
#  'would': 24,
#  'do': 24,
#  'by': 23,
#  'i': 23,
#  'go': 21,
#  'then': 21,
#  'so': 21,
#  'look': 21,
#  'over': 20,
#  'them': 20,
#  'when': 20,
#  'there': 20,
#  'not': 19,
#  'one': 19,
#  'home': 19,
#  'tree': 19,
#  'cow': 18,
#  'get': 18,
#  'all': 17,
#  'want': 17,
#  'rajaram': 17,
#  'no': 16,
#  'their': 16,
#  'if': 16,
#  'didn': 16,
#  'see': 16,
#  'man': 16,
#  'away': 16,
# ...

# %%
fdist2 = FreqDist(text2_tokenized)
print("\n\n\tPlot of 10 Tokens with maximum frequency in T2")
fdist2.plot(10)
# Out:
# 	Plot of 10 Tokens with maximum frequency in T2

# %%
zipf_dict2 = {}
a = sorted_dict2['the']
for w in sorted_dict2:
    zipf_dict2[w] = sorted_dict2[w]/a

zipf_dict2
# Out:
# {'the': 1.0,
#  'be': 0.40674603174603174,
#  'and': 0.40674603174603174,
#  'it': 0.3551587301587302,
#  'a': 0.3531746031746032,
#  'to': 0.31746031746031744,
#  'of': 0.26785714285714285,
#  'she': 0.25992063492063494,
#  'have': 0.25,
#  'binya': 0.21428571428571427,
#  'umbrella': 0.20833333333333334,
#  'he': 0.20238095238095238,
#  'in': 0.1984126984126984,
#  'her': 0.19047619047619047,
#  's': 0.1388888888888889,
#  'on': 0.11706349206349206,
#  'but': 0.11706349206349206,
#  'that': 0.11507936507936507,
#  'for': 0.10714285714285714,
#  'his': 0.10714285714285714,
#  'you': 0.10515873015873016,
#  't': 0.09722222222222222,
#  'with': 0.0873015873015873,
#  'bijju': 0.08531746031746032,
#  'ram': 0.08333333333333333,
#  'bharosa': 0.07936507936507936,
#  'say': 0.07539682539682539,
#  'as': 0.07341269841269842,
#  'they': 0.06547619047619048,
#  'come': 0.06547619047619048,
#  'up': 0.061507936507936505,
#  'shop': 0.061507936507936505,
#  'out': 0.05952380952380952,
# ...

# %%
fdist22 = FreqDist(zipf_dict2)
print("\n\n\tPlot of 10 Tokens with maximum frequency in T2")
fdist22.plot(10)
x = np.linspace(1, 10, 20)

y = 1/(x**0.8)

plt.plot(x, y, 'b')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph of 1/x')
plt.show()
# Out:
# 	Plot of 10 Tokens with maximum frequency in T2

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = list(zipf_dict2.keys())
y1 = list(zipf_dict2.values())
x2 = np.linspace(1, 10, 20)
y2 = 1/(x**0.65)

fig, ax1 = plt.subplots()

ax2 = ax1.twiny() 

curve1, = ax1.plot(x1[:10],y1[:10] , label="Novel", color='g')
curve2, = ax2.plot(x2, y2, label="1/x^(0.8)", color='b')

curves = [curve1, curve2]

ax1.legend() 
ax2.legend() 
ax1.legend(curves, [curve.get_label() for curve in curves])
ax2.legend(curves, [curve.get_label() for curve in curves]) 
plt.title("Graph between 1/x^(0.65) and T2")
plt.show()

# %%
print("\n\n\t\t\tWord Cloud of T1")
wordcloud = WordCloud(stopwords = ["."]).generate(text1)
plt.figure(figsize=(15,15))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

print("\n\n\t\t\tWord Cloud of T2")
wordcloud = WordCloud(stopwords = ["."]).generate(text2)
plt.figure(figsize=(15,15))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
# Out:
# 			Word Cloud of T1
# 			Word Cloud of T2

# %% [markdown]
# ## **After removing stopwords**

# %%
clean_words_t1 = []
clean_words_t2 = []
for w in text1_tokenized:
  if w not in stopwords:
    clean_words_t1.append(w)

fdist = FreqDist(clean_words_t1)
print("\n\nPlot of 10 Tokens with maximum frequency in T1 after removing stopwords")
fdist.plot(10)
# Out:
# Plot of 10 Tokens with maximum frequency in T1 after removing stopwords

# %%
clean_words_t2 = []
for w in text2_tokenized:
  if w not in stopwords:
    clean_words_t2.append(w)

fdist = FreqDist(clean_words_t2)
print("\n\nPlot of 10 Tokens with maximum frequency in T2 after removing stopwords")
fdist.plot(10)
# Out:
# Plot of 10 Tokens with maximum frequency in T2 after removing stopwords

# %%
print("\n\n\t\t\tWord Cloud of T1 after removing Stop Words")
wordcloud = WordCloud(stopwords = stopwords).generate(text1)
plt.figure(figsize=(15,15))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()

print("\n\n\t\t\tWord Cloud of T2 after removing Stop Words")
wordcloud = WordCloud(stopwords = stopwords).generate(text2)
plt.figure(figsize=(15,15))
plt.imshow(wordcloud)
plt.axis("off")
plt.show()
# Out:
# 			Word Cloud of T1 after removing Stop Words
# 			Word Cloud of T2 after removing Stop Words

# %%
wfreq1=[clean_words_t1.count(w) for w in clean_words_t1]
temp1 = {}
temp1 = (dict(zip(clean_words_t1,wfreq1)))
keys = temp1.keys()
values = temp1.values()

# %%
sorted_dict3 = {}
sorted_keys = sorted(temp1, key=temp1.get,reverse = True)  

for w in sorted_keys:
    sorted_dict3[w] = temp1[w]

print(sorted_dict3)
print(len(sorted_dict3))
# Out:
# {'say': 1717, 'riya': 408, 'want': 307, 'like': 289, 'go': 283, 'come': 272, 'look': 253, 'take': 217, 'know': 217, 'mother': 205, 'one': 189, 'madhav': 189, 'make': 185, 'would': 180, 'leave': 175, 'time': 170, 'get': 164, 'english': 161, 'back': 161, 'tell': 159, 'hand': 157, 'school': 155, 'think': 150, 'sit': 144, 'us': 139, 'could': 138, 'need': 138, 'shailesh': 136, 'even': 130, 'ask': 126, 'right': 122, 'see': 122, 'give': 121, 'yes': 121, 'well': 115, 'people': 111, 'call': 111, 'two': 106, 'face': 106, 'speak': 103, 'good': 101, 'place': 101, 'find': 99, 'sir': 99, 'walk': 99, 'head': 97, 'turn': 96, 'class': 95, 'talk': 94, 'smile': 92, 'stand': 91, 'college': 91, 'eye': 90, 'let': 90, 'try': 88, 'love': 88, 'girl': 88, 'something': 87, 'okay': 85, 'laugh': 84, 'felt': 84, 'mean': 83, 'room': 83, 'rohan': 81, 'friends': 80, 'meet': 80, 'still': 79, 'new': 78, 'much': 78, 'gate': 78, 'voice': 76, 'please': 76, 'run': 76, 'never': 76, 'three': 75, 'away': 74, 'sorry': 74, 'fi
# ...

# %%
zipf_dict3 = {}
a = sorted_dict3['say']
for w in sorted_dict3:
    zipf_dict3[w] = sorted_dict3[w]/a

zipf_dict3

# %%
fdist33 = FreqDist(zipf_dict3)
print("\n\n\tPlot of 10 Tokens with maximum frequency in T1")
fdist33.plot(10)
x = np.linspace(1, 10, 20)

y = 1/(x**0.4)

plt.plot(x, y, 'r')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph of 1/x')
plt.show()
# Out:
# 	Plot of 10 Tokens with maximum frequency in T1

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = list(zipf_dict3.keys())
y1 = list(zipf_dict3.values())
x2 = np.linspace(1, 10, 20)
y2 = 1/(x**1)

fig, ax1 = plt.subplots()

ax2 = ax1.twiny() 

curve1, = ax1.plot(x1[:10],y1[:10] , label="Novel", color='g')
curve2, = ax2.plot(x2, y2, label="1/x", color='b')

curves = [curve1, curve2]

ax1.legend() 
ax2.legend() 
ax1.legend(curves, [curve.get_label() for curve in curves])
ax2.legend(curves, [curve.get_label() for curve in curves]) 
plt.title("Graph between 1/x and T1")
plt.show()

# %%
wfreq2=[clean_words_t2.count(w) for w in clean_words_t2]
temp2 = {}
temp2 = (dict(zip(clean_words_t2,wfreq2)))
keys2 = temp2.keys()
values2 = temp2.values()

# %%
sorted_dict4 = {}
sorted_keys2 = sorted(temp2, key=temp2.get,reverse = True)  

for w in sorted_keys2:
    sorted_dict4[w] = temp2[w]

print(sorted_dict4)  
print(len(sorted_dict4))
# Out:
# {'binya': 108, 'umbrella': 105, 'bijju': 43, 'ram': 42, 'bharosa': 40, 'say': 38, 'come': 33, 'shop': 31, 'give': 28, 'blue': 26, 'would': 24, 'go': 21, 'look': 21, 'one': 19, 'home': 19, 'tree': 19, 'cow': 18, 'get': 18, 'want': 17, 'rajaram': 17, 'see': 16, 'man': 16, 'away': 16, 'way': 15, 'claw': 15, 'rain': 15, 'hold': 14, 'open': 14, 'could': 14, 'leave': 14, 'run': 13, 'hill': 13, 'call': 13, 'like': 13, 'know': 13, 'keep': 13, 'still': 13, 'village': 12, 'two': 12, 'use': 12, 'take': 12, 'sun': 12, 'sell': 11, 'grass': 11, 'time': 11, 'little': 11, 'turn': 11, 'people': 11, 'hand': 11, 'head': 11, 'begin': 11, 'old': 11, 'wind': 11, 'feet': 11, 'neelu': 10, 'make': 10, 'reach': 10, 'boy': 10, 'mother': 9, 'pretty': 9, 'small': 9, 'ask': 9, 'rupees': 9, 'place': 9, 'day': 9, 'right': 8, 'mean': 8, 'stream': 8, 'sometimes': 8, 'let': 8, 'later': 8, 'saw': 8, 'woman': 8, 'shake': 8, 'much': 8, 'pick': 8, 'near': 8, 'road': 7, 'without': 7, 'may': 7, 'three': 7, 'stop': 7, 'brigh
# ...

# %%
zipf_dict4 = {}
a = sorted_dict4['binya']
for w in sorted_dict4:
    zipf_dict4[w] = sorted_dict4[w]/a

zipf_dict4

# %%
fdist44 = FreqDist(zipf_dict4)
print("\n\n\tPlot of 10 Tokens with maximum frequency in T2")
fdist44.plot(10)
x = np.linspace(1, 10, 20)

y = 1/(x**0.4)

plt.plot(x, y, 'r')
plt.xlabel('X axis')
plt.ylabel('Y axis')
plt.title('Graph of 1/x')
plt.show()
# Out:
# 	Plot of 10 Tokens with maximum frequency in T2

# %%
import numpy as np
import matplotlib.pyplot as plt

x1 = list(zipf_dict4.keys())
y1 = list(zipf_dict4.values())
x2 = np.linspace(1, 10, 20)
y2 = 1/(x**0.6)

fig, ax1 = plt.subplots()

ax2 = ax1.twiny() 

curve1, = ax1.plot(x1[:10],y1[:10] , label="Novel", color='g')
curve2, = ax2.plot(x2, y2, label="1/x^(0.6)", color='b')

curves = [curve1, curve2]

ax1.legend() 
ax2.legend() 
ax1.legend(curves, [curve.get_label() for curve in curves])
ax2.legend(curves, [curve.get_label() for curve in curves]) 
plt.title("Graph between 1/x^(0.6) and T2")
plt.show()

# %%
print("The ratio of without stopwards and total vocabs for T1:")
print(len(sorted_dict3)/len(set(text1_tokenized)))
# Out:
# The ratio of without stopwards and total vocabs for T1:
# 0.9754819389855887

# %%
print("The ratio of without stopwards and total vocabs for T2:")
print(len(sorted_dict4)/len(set(text2_tokenized)))
# Out:
# The ratio of without stopwards and total vocabs for T2:
# 0.9120879120879121
